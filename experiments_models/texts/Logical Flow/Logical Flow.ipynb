# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="SushantGautam/roberta-large_overall-coherence", device=-1)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/tensorflow-test/Astonhack/lib/python3.10/site-packages/transformers/activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# File ~/tensorflow-test/Astonhack/lib/python3.10/site-packages/tf_keras/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from tf_keras import __internal__
#       4 from tf_keras import activations
#
# File ~/tensorflow-test/Astonhack/lib/python3.10/site-packages/tf_keras/__internal__/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from tf_keras.__internal__ import backend
#       4 from tf_keras.__internal__ import layers
#
# File ~/tensorflow-test/Astonhack/lib/python3.10/site-packages/tf_keras/__internal__/backend/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from tf_keras.src.backend import _initialize_variables as initialize_variables
#       4 from tf_keras.src.backend import track_variable
#
# File ~/tensorflow-test/Astonhack/lib/python3.10/site-packages/tf_keras/src/__init__.py:21
#      15 """Implementation of the TF-Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
# ---> 21 from tf_keras.src import applications
#      22 from tf_keras.src import distribute
#
# File ~/tensorflow-test/Astonhack/lib/python3.10/site-packages/tf_keras/src/applications/__init__.py:18
#      15 """Keras Applications are premade architectures with pre-trained weights."""
# ---> 18 from tf_keras.src.applications.convnext import ConvNeXtBase
#      19 from tf_keras.src.applications.convnext import ConvNeXtLarge
#
# File ~/tensorflow-test/Astonhack/lib/python3.10/site-packages/tf_keras/src/applications/convnext.py:26
#      25 import numpy as np
# ---> 26 import tensorflow.compat.v2 as tf
#      28 from tf_keras.src import backend
#
# File ~/tensorflow-test/Astonhack/lib/python3.10/site-packages/tensorflow/_api/v2/compat/v2/__init__.py:85
#      84 from tensorflow.python.ops.gen_data_flow_ops import dynamic_stitch # line: 736
# ---> 85 from tensorflow.python.ops.gen_experimental_dataset_ops import check_pinned # line: 701
#      86 from tensorflow.python.ops.gen_linalg_ops import matrix_square_root # line: 1913
#
# ImportError: cannot import name 'check_pinned' from 'tensorflow.python.ops.gen_experimental_dataset_ops' (/Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages/tensorflow/python/ops/gen_experimental_dataset_ops.py)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/tensorflow-test/Astonhack/lib/python3.10/site-packages/transformers/utils/import_utils.py:1863, in _LazyModule._get_module(self, module_name)
#    1862 try:
# -> 1863     return importlib.import_module("." + module_name, self.__name__)
#    1864 except Exception as e:
#
# File ~/tensorflow-test/Astonhack/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/tensorflow-test/Astonhack/lib/python3.10/site-packages/transformers/models/roberta/modeling_tf_roberta.py:27
#      25 import tensorflow as tf
# ---> 27 from ...activations_tf import get_tf_activation
#      28 from ...modeling_tf_outputs import (
#      29     TFBaseModelOutputWithPastAndCrossAttentions,
#      30     TFBaseModelOutputWithPoolingAndCrossAttentions,
#    (...)
#      36     TFTokenClassifierOutput,
#      37 )
#
# File ~/tensorflow-test/Astonhack/lib/python3.10/site-packages/transformers/activations_tf.py:27
#      26     if parse(keras.__version__).major > 2:
# ---> 27         raise ValueError(
#      28             "Your currently installed version of Keras is Keras 3, but this is not yet supported in "
#      29             "Transformers. Please install the backwards-compatible tf-keras package with "
#      30             "`pip install tf-keras`."
#      31         )
#      34 def _gelu(x):
#
# ValueError: Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 4
#       1 # Use a pipeline as a high-level helper
#       2 from transformers import pipeline
# ----> 4 pipe = pipeline("text-classification", model="SushantGautam/roberta-large_overall-coherence", device=-1)
#
# File ~/tensorflow-test/Astonhack/lib/python3.10/site-packages/transformers/pipelines/__init__.py:940, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     938 if isinstance(model, str) or framework is None:
#     939     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 940     framework, model = infer_framework_load_model(
#     941         model,
#     942         model_classes=model_classes,
#     943         config=config,
#     944         framework=framework,
#     945         task=task,
#     946         **hub_kwargs,
#     947         **model_kwargs,
#     948     )
#     950 model_config = model.config
#     951 hub_kwargs["_commit_hash"] = model.config._commit_hash
#
# File ~/tensorflow-test/Astonhack/lib/python3.10/site-packages/transformers/pipelines/base.py:265, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     263         classes.append(_class)
#     264 if look_tf:
# --> 265     _class = getattr(transformers_module, f"TF{architecture}", None)
#     266     if _class is not None:
#     267         classes.append(_class)
#
# File ~/tensorflow-test/Astonhack/lib/python3.10/site-packages/transformers/utils/import_utils.py:1852, in _LazyModule.__getattr__(self, name)
#    1850 elif name in self._class_to_module.keys():
#    1851     module = self._get_module(self._class_to_module[name])
# -> 1852     value = getattr(module, name)
#    1853 elif name in self._modules:
#    1854     value = self._get_module(name)
#
# File ~/tensorflow-test/Astonhack/lib/python3.10/site-packages/transformers/utils/import_utils.py:1851, in _LazyModule.__getattr__(self, name)
#    1849     value = Placeholder
#    1850 elif name in self._class_to_module.keys():
# -> 1851     module = self._get_module(self._class_to_module[name])
#    1852     value = getattr(module, name)
#    1853 elif name in self._modules:
#
# File ~/tensorflow-test/Astonhack/lib/python3.10/site-packages/transformers/utils/import_utils.py:1865, in _LazyModule._get_module(self, module_name)
#    1863     return importlib.import_module("." + module_name, self.__name__)
#    1864 except Exception as e:
# -> 1865     raise RuntimeError(
#    1866         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1867         f" traceback):\n{e}"
#    1868     ) from e
#
# RuntimeError: Failed to import transformers.models.roberta.modeling_tf_roberta because of the following error (look up to see its traceback):
# Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.

# %%
text = "The story of Sarah Edmonds is a case in point. Born in 1841 in Canada (she later moved to Michigan), Sarah chafed from the lack of career opportunities available to young women in the mid-nineteenth century. Her choices ranged from low-paying menial jobs to the profession of last resort: prostitution. Sarah, therefore, reasoned that because good jobs went to men, she would become one; she cut her hair short, put on men’s clothing and adopted the name Franklin Thompson. Although delicate looking, Sarah acted convincingly enough as a male not only to pass as one but also to successfully gain jobs available to men. She became a book salesman and made a substantial amount of money excelling at this occupation. Because of this success, Sarah had to be extremely careful not to let her guard down and reveal who she really was."

text2 = ["Do you like playing outside?", "I like ice cream"]
text3 = ["What is your favorite animal?", "I like dogs!"]
text4 = ["How would you approach solving a complex problem with multiple components?",
        "To solve a complex problem with multiple components, I would start by breaking it down into smaller, manageable parts. First, I would analyze each component to understand its role and how it fits into the overall problem. After identifying key areas that need focus, I would prioritize them based on their impact and dependencies. Next, I would research and gather necessary information for each part and devise solutions using structured methods such as design thinking or systems thinking. Throughout the process, I would regularly test and iterate, ensuring each part is working efficiently before integrating everything into a final solution. Collaboration and communication with relevant stakeholders would be key to ensure alignment and identify any potential roadblocks early on."]
text5 = ["How would you approach solving a complex problem with multiple components?",
        "To solve a complex problem, I would simply try to do everything at once. I wouldn’t bother breaking it down into smaller parts because that would take too long. Instead, I’d just dive in and start solving everything simultaneously, hoping that it would all magically come together. If something goes wrong, I would ignore it and keep going, because stopping would be a waste of time. As for working with others, I don’t think it’s necessary; it’s faster if I just do everything myself. Eventually, the problem will solve itself, and if it doesn’t, I’ll try again next time, but quicker."]
sentence4 = "So this python piece of shit is just being annoying. It can go fucking kill itself. Um, yeah, you're right. Yeah, I'm having issues with type errors all over the place, with list indices being integers or slices, not tuffles. I don't know. Vibe coding doesn't really work very well in this situation."

# %%
pipe.predict(sentence4)
# Out:
# [{'label': 'LABEL_0', 'score': 0.5605596899986267}]

# %%
import pickle

# %%
with open ('logical_model.pk', 'wb') as f:
    pickle.dump(pipe, f)

# %%
# !pip install tf-keras
# Out:
# Requirement already satisfied: tf-keras in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (2.19.0)
# Collecting tensorflow<2.20,>=2.19 (from tf-keras)
#   Using cached tensorflow-2.19.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (4.0 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.32.3)
# Requirement already satisfied: setuptools in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.71.0)
# Collecting tensorboard~=2.19.0 (from tensorflow<2.20,>=2.19->tf-keras)
#   Using cached tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.5.0 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.9.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.13.0)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow<2.20,>=2.19->tf-keras)
#   Using cached ml_dtypes-0.5.1-cp310-cp310-macosx_10_9_universal2.whl.metadata (21 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19->tf-keras) (0.45.1)
# Requirement already satisfied: rich in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (13.9.4)
# Requirement already satisfied: namex in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.0.8)
# Requirement already satisfied: optree in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.14.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/widss/tensorflow-test/Astonhack/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.1.2)
# Using cached tensorflow-2.19.0-cp310-cp310-macosx_12_0_arm64.whl (252.5 MB)
# Using cached ml_dtypes-0.5.1-cp310-cp310-macosx_10_9_universal2.whl (671 kB)
# Using cached tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
# Installing collected packages: ml-dtypes, tensorboard, tensorflow
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.3.2
#     Uninstalling ml-dtypes-0.3.2:
#       Successfully uninstalled ml-dtypes-0.3.2
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.16.2
#     Uninstalling tensorboard-2.16.2:
#       Successfully uninstalled tensorboard-2.16.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.16.2
#     Uninstalling tensorflow-2.16.2:
#       Successfully uninstalled tensorflow-2.16.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-macos 2.16.2 requires tensorflow==2.16.2; platform_system == "Darwin" and platform_machine == "arm64", but you have tensorflow 2.19.0 which is incompatible.
# Successfully installed ml-dtypes-0.5.1 tensorboard-2.19.0 tensorflow-2.19.0

# %%
import transformers

# %%
transformers.__version__
# Out:
# '4.49.0'
